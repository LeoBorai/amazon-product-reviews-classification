# %%
import pandas as pd

df = pd.read_csv('../datasets/reviews.csv')

# %%
df.head()
# Out:
#                      id       asins   brand                  categories  \
# 0  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 1  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 2  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 3  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 4  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
#
#   colors             dateAdded           dateUpdated  \
# 0    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 1    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 2    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 3    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 4    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
#
#                   dimension  ean                         keys  ...  \
# 0  169 mm x 117 mm x 9.1 mm  NaN  kindlepaperwhite/b00qjdu3ky  ...
# 1  169 mm x 117 mm x 9.1 mm  NaN  kindlepaperwhite/b00qjdu3ky  ...
# ...

# %%
print('Number of reviews: ', len(df))
# Out:
# Number of reviews:  1597

# %% [markdown]
# ## Data Cleansing
#
# Some of the columns are not relevant, as well there could be samples in other languages which would affect accurancy of the resulting model.

# %% [markdown]
# `reviews.csv` counts with 1597 review samples. Some of the columns are not relevant for our model trainning, relevant columns are:
# - `reviews.rating`
# - `reviews.title`
# - `reviews.text`
#
# Other columns can be dropped.

# %%
df = df.filter(['reviews.rating', 'reviews.title', 'reviews.text'], axis=1)
df.head(10)
# Out:
#    reviews.rating                                      reviews.title  \
# 0             5.0                     Paperwhite voyage, no regrets!
# 1             5.0                  One Simply Could Not Ask For More
# 2             4.0         Great for those that just want an e-reader
# 3             5.0                           Love / Hate relationship
# 4             5.0                                          I LOVE IT
# 5             NaN  Great device for reading. 8 people found this ...
# 6             NaN  One Simply Could Not Ask For More 28 people fo...
# 7             NaN  Definitely better than the previous generation...
# 8             NaN  Paperwhite voyage, no regrets! 16 people found...
# 9             NaN  Great for those that just want an e-reader 19 ...
#
#                                         reviews.text
# 0  I initially had trouble deciding between the p...
# 1  Allow me to preface this with a little history...
# ...

# %%
# rename collums to remove dots
df = df.rename({ 'reviews.rating': 'rating', 'reviews.title': 'title', 'reviews.text': 'text' }, axis=1)

# %%
df.head(10)
# Out:
#    rating                                              title  \
# 0     5.0                     Paperwhite voyage, no regrets!
# 1     5.0                  One Simply Could Not Ask For More
# 2     4.0         Great for those that just want an e-reader
# 3     5.0                           Love / Hate relationship
# 4     5.0                                          I LOVE IT
# 5     NaN  Great device for reading. 8 people found this ...
# 6     NaN  One Simply Could Not Ask For More 28 people fo...
# 7     NaN  Definitely better than the previous generation...
# 8     NaN  Paperwhite voyage, no regrets! 16 people found...
# 9     NaN  Great for those that just want an e-reader 19 ...
#
#                                                 text
# 0  I initially had trouble deciding between the p...
# 1  Allow me to preface this with a little history...
# 2  I am enjoying it so far. Great for reading. Ha...
# 3  I bought one of the first Paperwhites and have...
# ...

# %%
# NaN ratings are not useful, so these should be removed
df.dropna(subset=['rating'])
# Out:
#       rating                                              title  \
# 0        5.0                     Paperwhite voyage, no regrets!
# 1        5.0                  One Simply Could Not Ask For More
# 2        4.0         Great for those that just want an e-reader
# 3        5.0                           Love / Hate relationship
# 4        5.0                                          I LOVE IT
# ...      ...                                                ...
# 1592     3.0  I would be disappointed with myself if i produ...
# 1593     1.0                        Battery draining remote!!!!
# 1594     1.0      replacing an even worse remote. Waste of time
# 1595     3.0                                         Overpriced
# 1596     1.0  I am sending all of this crap back to amazon a...
#
#                                                    text
# 0     I initially had trouble deciding between the p...
# 1     Allow me to preface this with a little history...
# ...

# %% [markdown]
# Our model should only classify english comments so predictions are more accurate. Reviews in other languages should be filtered out.

# %%
from langdetect import detect

def detect_english(title, text):
    if detect(title) == 'en' and detect(text) == 'en':
        return 'en'
    return 'unknown'

df['lang'] = df.apply(lambda x: detect_english(x.title, x.text), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       5         return 'en'
#       6     return 'unknown'
# ----> 8 df['lang'] = df.apply(lambda x: detect_english(x.title, x.text), axis=1)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# ...

# %%
# Suspect theres some NaNs affecting `detect`
df.isna().sum()
# Out:
# rating    420
# title      17
# text        0
# dtype: int64

# %%
df = df.dropna(subset=['rating'])
df.head(10)
# Out:
#     rating                                              title  \
# 0      5.0                     Paperwhite voyage, no regrets!
# 1      5.0                  One Simply Could Not Ask For More
# 2      4.0         Great for those that just want an e-reader
# 3      5.0                           Love / Hate relationship
# 4      5.0                                          I LOVE IT
# 13     4.0                             Liked the smaller size
# 14     5.0  Superb reading device - but which one's best f...
# 15     5.0                                         I love it!
# 16     4.0                                         Un plaisir
# 17     5.0          Works great and I love the built-in light
#
#                                                  text
# 0   I initially had trouble deciding between the p...
# 1   Allow me to preface this with a little history...
# 2   I am enjoying it so far. Great for reading. Ha...
# 3   I bought one of the first Paperwhites and have...
# ...

# %%
df = df.dropna(subset=['title'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1177 entries, 0 to 1596
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rating  1177 non-null   float64
#  1   title   1177 non-null   object
#  2   text    1177 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 36.8+ KB

# %%
df['lang'] = df.apply(lambda x: detect_english(x.title, x.text), axis=1)
df.head(10)
# Out:
#     rating                                              title  \
# 0      5.0                     Paperwhite voyage, no regrets!
# 1      5.0                  One Simply Could Not Ask For More
# 2      4.0         Great for those that just want an e-reader
# 3      5.0                           Love / Hate relationship
# 4      5.0                                          I LOVE IT
# 13     4.0                             Liked the smaller size
# 14     5.0  Superb reading device - but which one's best f...
# 15     5.0                                         I love it!
# 16     4.0                                         Un plaisir
# 17     5.0          Works great and I love the built-in light
#
#                                                  text     lang
# 0   I initially had trouble deciding between the p...  unknown
# 1   Allow me to preface this with a little history...       en
# 2   I am enjoying it so far. Great for reading. Ha...       en
# ...

# %% [markdown]
# Seems like some of the rows now has `unkown`, this should be due to a limitation in `langdetect` or due to the exclusivity of the `detect_english`.

# %%
df['lang'].value_counts()
# Out:
# lang
# en         950
# unknown    227
# Name: count, dtype: int64

# %% [markdown]
# Index 16 above is crearly French, but theres other cases like Index 15 where is English but there is a small percentage of French by using `fiance`, this might affect detection.

# %%
from langdetect import detect_langs

detect_langs('I love my kindle! I got one for my fiance on...')
# Out:
# [en:0.9999944771444464]

# %%
detect_langs('Vraiment bon petit appareil , lger et facile d...')
# Out:
# [fr:0.9999972864118577]

# %%
print(df.loc[[15]])
# Out:
#     rating       title                                               text  \
# 15     5.0  I love it!  I love my kindle! I got one for my fiance on h...
#
#        lang
# 15  unknown

# %% [markdown]
# Lets ease a bit the detection to allow either title or text to be English in order to determine wether the language is English, this could affect precision but might also bring in more samples to train the classification model.

# %%
from langdetect import detect

def detect_english(title, text):
    if detect(title) == 'en' or detect(text) == 'en':
        return 'en'
    return 'unknown'

df['lang'] = df.apply(lambda x: detect_english(x.title, x.text), axis=1)

# %%
df['lang'].value_counts()
# Out:
# lang
# en         1173
# unknown       4
# Name: count, dtype: int64

# %% [markdown]
# This change brough in almost 98% of our samples! Now other items which are not English could be removed.

# %%
df = df.query('lang == "en"')
df['lang'].value_counts()
# Out:
# lang
# en    1173
# Name: count, dtype: int64

# %% [markdown]
# ## Transforming Data
#
# Prepare data for trainning, the dataset is splitted using Pareto Principle (80/20), then data is transformed to satisfy algorithm requirements.

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

reviews = df['text'].values
ratings = df['rating'].values

reviews_train, reviews_test, y_train, y_test = train_test_split(reviews,
                                                               ratings, test_size=0.2, random_state=1000)

vectorizer = CountVectorizer()
vectorizer.fit(reviews_train)
x_train = vectorizer.transform(reviews_train)
x_test = vectorizer.transform(reviews_test)

# %%
# Train Model
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Should extend max iterations (default to 100) to achieve covergence, the algorithm used behind
# scenes is "Limited-memory Broyden–Fletcher–Goldfarb–Shanno Algorithm" which performs better in
# smaller datasets. Extending maximum interations will NOT GUARANTEE COVERGENCE but might help.

# %%
classifier = LogisticRegression(solver='lbfgs', max_iter=1000)
classifier.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ### Testing Model
#
# Using the remaining `x_test` dataset we can test our model.

# %%
import numpy as np

predicted = classifier.predict(x_test)
accurancy = np.mean(predicted == y_test)

print('Accurancy: ', round(accurancy,2))
# Out:
# Accurancy:  0.67

# %% [markdown]
# Apply _Confusion Matrix_ metric on model to determine wether the model could mislabel classes.

# %%
from sklearn import metrics

RATINGS = [1, 2, 3, 4, 5]

print(metrics.confusion_matrix(y_test, predicted, labels = RATINGS))
# Out:
# [[  1   0   1   2   0]
#  [  0   2   0   1   6]
#  [  0   1  16   2   9]
#  [  1   0   2  15  32]
#  [  2   1   1  16 124]]

# %% [markdown]
# The main diagonal compound by:
#
# {1, 2, 16, 15, 124}
#
# Shows that the model made 124 correct predictions for 5 star reviews and dropped to 15 correct predictions for 4 star reviews, predictions for 3 star reviews are also closer to 4 star review performance.
#
# For 1 star and 2 stars it drops to 1 and 2 respectively.

# %% [markdown]
# Predictions on 5 star reviews outstands other reviews, this might be due to a higher presence of 5 stars reviews in the dataset than for other classes (4 and others).

# %%
print(df.groupby('rating').size())
# Out:
# rating
# 1.0     42
# 2.0     34
# 3.0    124
# 4.0    233
# 5.0    740
# dtype: int64

# %% [markdown]
# > The model didn't have enough samples to classify other ratings as it has for 5 star reviews.

# %%
print(metrics.classification_report(y_test, predicted, labels = RATINGS))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.25      0.25      0.25         4
#            2       0.50      0.22      0.31         9
#            3       0.80      0.57      0.67        28
#            4       0.42      0.30      0.35        50
#            5       0.73      0.86      0.79       144
#
#     accuracy                           0.67       235
#    macro avg       0.54      0.44      0.47       235
# weighted avg       0.65      0.67      0.65       235

# %% [markdown]
# The support metric shows the number of samples per class of ratings, showing that for 5 star ratings we have 144 while we have 50 for 4 stars and drops event more on subsequent classes.

# %%
Metrics on accurancy per class is show as percentage in the `recall` metric,
